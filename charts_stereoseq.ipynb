# %%
import pandas as pd
import matplotlib.pyplot as plt


# Set global font sizes
plt.rcParams.update({
    'font.size': 20,          # Default font size
    'axes.titlesize': 20,     # Title font size
    'axes.labelsize': 20,     # x and y label font size
    'xtick.labelsize': 20,    # x tick font size
    'ytick.labelsize': 20,    # y tick font size
    'legend.fontsize': 20,    # Legend font size
    'figure.titlesize': 20    # Figure title font size
})

# %% [markdown]
# ### stereoseq

# %%
# Create the data
data_next_step_ti4 = {
    "variant": [
        "EOT",
        "PACM g+mc",
        "PACM g+lr",
        "PACM g+mc+lr",
        "PROT+mc",
        "PROT+lr",
        "PROT+mc+lr"
    ],
    "W. Wasserstein": [7.61876, 6.96753, 7.24386, 7.18755, 6.91389, 7.50542, 7.24325],
    "Wasserstein": [7.76872, 6.96932, 7.14566, 6.93054, 7.19808, 7.33777, 7.15655],
    "MMD": [0.27230, 0.26484, 0.26549, 0.26694, 0.26553, 0.26327, 0.27044],
    "Energy": [85.35222, 77.02492, 80.42356, 78.99226, 76.14891, 83.42541, 79.82577]
}

data_ivp_ti4 = {
    "variant": [
        "EOT",
        "PACM g+mc",
        "PACM g+lr",
        "PACM g+mc+lr",
        "PROT+mc",
        "PROT+lr",
        "PROT+mc+lr"
    ],
    "W. Wasserstein": [6.50278, 6.26005, 6.61417, 6.69574, 6.24341, 5.27727, 6.25417],
    "Wasserstein": [6.35232, 7.68145, 6.85441, 6.48077, 6.22021, 6.02101, 5.97306],
    "MMD": [0.16199, 0.15735, 0.20132, 0.19451, 0.19532, 0.09869, 0.15649],
    "Energy": [56.45227, 52.47819, 70.36996, 66.21228, 61.31561, 27.77688, 54.32978]
}



data_next_step_ti3 = {
    "variant": [
        "EOT",
        "PACM g+mc",
        "PACM g+lr",
        "PACM g+mc+lr",
        "PROT+mc",
        "PROT+lr",
        "PROT+mc+lr"
    ],
    "W. Wasserstein": [4.48092, 4.31644, 4.33720, 4.31566, 4.41278, 4.89998, 4.43284],
    "Wasserstein": [4.61222, 4.62603, 4.54887, 4.54512, 4.62648, 5.70507, 4.53802],
    "MMD": [0.19908, 0.19873, 0.19858, 0.19828, 0.19825, 0.19404, 0.19878],
    "Energy": [37.41026, 37.29539, 37.06610, 36.82700, 36.92534, 45.90645, 37.27129]
}


# Create the fourth dataset
data_ivp_ti3 = {
    "variant": [
        "EOT",
        "PACM g+mc",
        "PACM g+lr",
        "PACM g+mc+lr",
        "PROT+mc",
        "PROT+lr",
        "PROT+mc+lr"
    ],
    "W. Wasserstein": [3.44353, 3.17249, 3.15467, 3.20721, 3.19248, 5.61431, 3.12860],
    "Wasserstein": [3.28952, 3.15116, 2.92573, 3.05469, 2.97779, 7.31138, 2.87443],
    "MMD": [0.28009, 0.28245, 0.27076, 0.27517, 0.26386, 0.22357, 0.27217],
    "Energy": [28.03941, 26.63352, 24.16729, 25.45053, 23.47035, 61.52824, 24.38541]

}


data_next_step_ti2 = {
    "variant": [
        "EOT",
        "PACM g+mc",
        "PACM g+lr",
        "PACM g+mc+lr",
        "PROT+mc",
        "PROT+lr",
        "PROT+mc+lr"
    ],
    "W. Wasserstein": [2.56698, 2.42266, 2.39623, 2.44222, 2.52765, 2.31600, 2.51862],
    "Wasserstein": [2.47587, 2.29347, 2.09952, 2.35273, 2.53424, 1.96938, 2.41187],
    "MMD": [0.04047, 0.03664, 0.03335, 0.03456, 0.03999, 0.02966, 0.03853],
    "Energy": [11.26859, 9.87364, 8.57715, 9.00812, 11.19206, 6.35925, 10.30397]
}


data_ivp_ti2 = {
    "variant": [
        "EOT",
        "PACM g+mc",
        "PACM g+lr",
        "PACM g+mc+lr",
        "PROT+mc",
        "PROT+lr",
        "PROT+mc+lr"
    ],
    "W. Wasserstein": [4.19813, 3.60320, 3.46488, 4.01528, 3.92486, 3.90544, 3.91711],
    "Wasserstein": [4.45167, 3.81637, 3.64065, 3.97434, 4.37474, 4.18803, 4.15918],
    "MMD": [0.17275, 0.12693, 0.11851, 0.13950, 0.16368, 0.07437, 0.14682],
    "Energy": [33.14853, 24.27061, 23.05491, 27.59223, 32.03379, 18.72814, 29.61300]
}

# %%
settings= [
        "EOT",
        # "PACM g+mc",
        "PACM g+lr",
        "PACM g+mc+lr",
        # "PROT+mc",
        "PROT+lr",
        "PROT+mc+lr"
    ]
# Convert to DataFrame
df_ivp4 = pd.DataFrame(data_ivp_ti4)
df_next_step4 = pd.DataFrame(data_next_step_ti4)

df_ivp3 = pd.DataFrame(data_ivp_ti3)
df_next_step3 = pd.DataFrame(data_next_step_ti3)

df_ivp2 = pd.DataFrame(data_ivp_ti2)
df_next_step2 = pd.DataFrame(data_next_step_ti2)

df_ivp4 = df_ivp4 [df_ivp4["variant"].isin(settings)]
df_next_step4 = df_next_step4 [df_next_step4["variant"].isin(settings)]

df_ivp3 = df_ivp3 [df_ivp3["variant"].isin(settings)]
df_next_step3 = df_next_step3 [df_next_step3["variant"].isin(settings)]

df_ivp2 = df_ivp2 [df_ivp2["variant"].isin(settings)]
df_next_step2 = df_next_step2 [df_next_step2["variant"].isin(settings)]

# %% [markdown]
# ## Wassersteins

# %%
# # Plot 1
plt.figure(figsize=(12, 6))
# metrics = ["Wasserstein"]
metrics = ["W. Wasserstein"]

for metric in metrics:
    # plt.plot(df_ivp2["variant"], df_ivp2[metric], marker="o", label=metric+"2")
    # plt.plot(df_ivp3["variant"], df_ivp3[metric], marker="o", label=metric+"3")
    plt.plot(df_ivp4["variant"], df_ivp4[metric], marker="o", label=metric+"4")

plt.title("IVP Evaluation")
plt.xlabel("Variant")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()


# # Plot 2
plt.figure(figsize=(12, 6))
# metrics = ["Wasserstein"]
metrics = ["W. Wasserstein"]

for metric in metrics:
    plt.plot(df_next_step2["variant"], df_next_step2[metric], marker="o", label=metric+"timestep: 2")
    # plt.plot(df_next_step3["variant"], df_next_step3[metric], marker="o", label=metric+"timestep: 3")
    plt.plot(df_next_step4["variant"], df_next_step4[metric], marker="o", label=metric+"timestep: 4")

plt.title("Next Step Evaluation")
plt.xlabel("Variant")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()



# # Plot 3
plt.figure(figsize=(12, 6))
# metrics = ["Wasserstein"]
metrics = ["W. Wasserstein"]

for metric in metrics:
    # plt.plot(df_ivp2["variant"], df_ivp2[metric], marker="o", label='IVP: '+metric)
    # plt.plot(df_ivp3["variant"], df_ivp3[metric], marker="o", label='IVP: '+metric)
    # plt.plot(df_ivp4["variant"], df_ivp4[metric], marker="o", label='IVP: '+metric)

    # plt.plot(df_next_step2["variant"], df_next_step2[metric], marker="o", label='Next Step: '+metric)
    # plt.plot(df_next_step3["variant"], df_next_step3[metric], marker="o", label='Next Step: '+metric)
    # plt.plot(df_next_step4["variant"], df_next_step4[metric], marker="o", label='Next Step: '+metric)

plt.title("IVP and Next Step Evaluation")
plt.xlabel("Variant")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()


# # Plot 4
def rel_to_baseline(s): 
    base = s.iloc[0]
    return 100*(s/base - 1.0)

plt.figure(figsize=(12,6))
plt.plot(df_ivp2['variant'], rel_to_baseline(df_ivp2['Wasserstein']), marker='o', label='IVP: Wasserstein')
plt.plot(df_next_step2['variant'], rel_to_baseline(df_next_step2['Wasserstein']), marker='s', label='Next Step: Wasserstein')

# plt.plot(df_ivp3['variant'], rel_to_baseline(df_ivp3['Wasserstein']), marker='o', label='IVP: Wasserstein')
# plt.plot(df_next_step3['variant'], rel_to_baseline(df_next_step3['Wasserstein']), marker='s', label='Next Step: Wasserstein')

# plt.plot(df_ivp4['variant'], rel_to_baseline(df_ivp4['Wasserstein']), marker='o', label='IVP: Wasserstein')
# plt.plot(df_next_step4['variant'], rel_to_baseline(df_next_step4['Wasserstein']), marker='s', label='Next Step: Wasserstein')

plt.axhline(0, color='gray', lw=1, alpha=0.5)
plt.ylabel('% change vs M-OT'); plt.xlabel('Variant'); plt.legend(); plt.grid(True); plt.xticks(rotation=20)
plt.title("Relative improvement of Variants (Wasserstein)")
plt.tight_layout(); plt.show()


# # Plot 5
def rel_to_baseline(s): 
    base = s.iloc[0]
    return 100*(s/base - 1.0)

plt.figure(figsize=(12,6))
plt.plot(df_ivp2['variant'], rel_to_baseline(df_ivp2['W. Wasserstein']), marker='o', label='IVP: W. Wasserstein')
plt.plot(df_next_step2['variant'], rel_to_baseline(df_next_step2['W. Wasserstein']), marker='s', label='Next Step: W. Wasserstein')

# plt.plot(df_ivp3['variant'], rel_to_baseline(df_ivp3['W. Wasserstein']), marker='o', label='IVP: W. Wasserstein')
# plt.plot(df_next_step3['variant'], rel_to_baseline(df_next_step3['W. Wasserstein']), marker='s', label='Next Step: W. Wasserstein')

# plt.plot(df_ivp4['variant'], rel_to_baseline(df_ivp4['W. Wasserstein']), marker='o', label='IVP: W. Wasserstein')
# plt.plot(df_next_step4['variant'], rel_to_baseline(df_next_step4['W. Wasserstein']), marker='s', label='Next Step: W. Wasserstein')

plt.axhline(0, color='gray', lw=1, alpha=0.5)
plt.ylabel('% change vs M-OT'); plt.xlabel('Variant'); plt.legend(); plt.grid(True); plt.xticks(rotation=20)
plt.title("Relative improvement of Variants (W. Wasserstein)")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## MMD

# %%
# # Plot 1
plt.figure(figsize=(12, 6))
metrics = ["MMD"]

for metric in metrics:
    plt.plot(df_ivp2["variant"], df_ivp2[metric], marker="o", label=metric+"timestep: 2")
    # plt.plot(df_ivp3["variant"], df_ivp3[metric], marker="o", label=metric+"timestep: 3")
    # plt.plot(df_ivp4["variant"], df_ivp4[metric], marker="o", label=metric+"timestep: 4")

plt.title("IVP Evaluation")
plt.xlabel("Variant")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()


# # Plot 2
plt.figure(figsize=(12, 6))
metrics = ["MMD"]

for metric in metrics:
    plt.plot(df_next_step2["variant"], df_next_step2[metric], marker="o", label=metric+"2")
    # plt.plot(df_next_step3["variant"], df_next_step3[metric], marker="o", label=metric+"3")
    # plt.plot(df_next_step4["variant"], df_next_step4[metric], marker="o", label=metric+"4")

plt.title("Next Step Evaluation")
plt.xlabel("Variant")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()


# # Plot 3
def rel_to_baseline(s): 
    base = s.iloc[0]
    return 100*(s/base - 1.0)

plt.figure(figsize=(12,6))
plt.plot(df_ivp2['variant'], rel_to_baseline(df_ivp2['MMD']), marker='o', label='IVP: MMD')
plt.plot(df_next_step2['variant'], rel_to_baseline(df_next_step2['MMD']), marker='s', label='Next Step: MMD')

# plt.plot(df_ivp3['variant'], rel_to_baseline(df_ivp3['MMD']), marker='o', label='IVP: MMD')
# plt.plot(df_next_step3['variant'], rel_to_baseline(df_next_step3['MMD']), marker='s', label='Next Step: MMD')

# plt.plot(df_ivp4['variant'], rel_to_baseline(df_ivp4['MMD']), marker='o', label='IVP: MMD')
# plt.plot(df_next_step4['variant'], rel_to_baseline(df_next_step4['MMD']), marker='s', label='Next Step: MMD')

plt.axhline(0, color='gray', lw=1, alpha=0.5)
plt.ylabel('% change vs M-OT'); plt.xlabel('Variant'); plt.legend(); plt.grid(True); plt.xticks(rotation=20)
plt.title("Relative improvement of Variants (MMD)")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Energy

# %%
# Plot 1
plt.figure(figsize=(12, 6))
metrics = ["Energy"]

for metric in metrics:
    plt.plot(df_ivp2["variant"], df_ivp2[metric], marker="o", label=metric+"2")
    # plt.plot(df_ivp3["variant"], df_ivp3[metric], marker="o", label=metric+"3")
    # plt.plot(df_ivp4["variant"], df_ivp4[metric], marker="o", label=metric+"4")


plt.title("IVP Evaluation: Energy")
plt.xlabel("Variant")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()


# Plot 2
plt.figure(figsize=(12, 6))
metrics = ["Energy"]

for metric in metrics:
    plt.plot(df_next_step2["variant"], df_next_step2[metric], marker="o", label=metric+"2")
    # plt.plot(df_next_step3["variant"], df_next_step3[metric], marker="o", label=metric+"3")
    # plt.plot(df_next_step4["variant"], df_next_step4[metric], marker="o", label=metric+"4")


plt.title("Next Step Evaluation: Energy")
plt.xlabel("Variant")
plt.ylabel("Metric Value")
plt.legend()
plt.grid(True)
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()


# # Plot 3
def rel_to_baseline(s): 
    base = s.iloc[0]
    return 100*(s/base - 1.0)

plt.figure(figsize=(12,6))
plt.plot(df_ivp2['variant'], rel_to_baseline(df_ivp2['Energy']), marker='o', label='IVP: Energy')
plt.plot(df_next_step2['variant'], rel_to_baseline(df_next_step2['Energy']), marker='s', label='Next Step: Energy')

# plt.plot(df_ivp3['variant'], rel_to_baseline(df_ivp3['Energy']), marker='o', label='IVP: Energy')
# plt.plot(df_next_step3['variant'], rel_to_baseline(df_next_step3['Energy']), marker='s', label='Next Step: Energy')

# plt.plot(df_ivp4['variant'], rel_to_baseline(df_ivp4['Energy']), marker='o', label='IVP: Energy')
# plt.plot(df_next_step4['variant'], rel_to_baseline(df_next_step4['Energy']), marker='s', label='Next Step: Energy')


plt.axhline(0, color='gray', lw=1, alpha=0.5)
plt.ylabel('% change vs M-OT'); plt.xlabel('Variant'); plt.legend(); plt.grid(True); plt.xticks(rotation=20)
plt.title("Relative improvement of Variants (Energy)")
plt.tight_layout(); plt.show()
